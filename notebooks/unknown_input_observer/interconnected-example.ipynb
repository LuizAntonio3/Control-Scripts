# %%
import control as ct
import matplotlib.pyplot as plt
import math
import numpy as np
import cvxpy as cp
import networkx as ntx
from scipy.integrate import solve_ivp
import os
import copy

from control_utils.politopic_representation import *

rng = np.random.default_rng()

# %%
# RLC circuit
A = np.array([
    [0, 1],
    [-9.81/.1, 0]
])

C = np.array([1, 0]).reshape(1, 2)

np.linalg.eigvals(A), np.linalg.matrix_rank(ct.obsv(A, C)) == A.shape[0]
# Out:
# (array([0.+9.90454441j, 0.-9.90454441j]), np.True_)

# %%
# constants
D = [1, 2, 3]
M = [1, 2, 3]
R = [1, 2, 3]
K = [1, 2, 3]
T = [1, 2, 3]

# D = np.array(D)
# M = np.array(M)
# R = np.array(R)
# K = np.array(K)
# T = np.array(T)

# simulation time
time = 10
eps = 1e-9
eta = 1

# hyperplanes
a_i = np.array([
    [1, -1, 0, 0],
    [0, 0, 1, -1]
])
b_i = np.array([5, 5, 10, 10]).reshape(4, 1)+1
bR_i = np.array([5, 5, 10, 10]).reshape(4, 1)

# Connections Graph construction
N = 3

# Connections btw systems & Initial States
if N == 3:
    E_half = [(1, 2), (2, 3)] # N = 3
    x0 = np.array([2, 2, 3, -2, -2, -2, 0, 0, 0, 0, 0, 0]) # N = 3
elif N == 4:
    pass
else:
    pass

G = ntx.Graph()
G.add_nodes_from(range(1, N+1))
G.add_edges_from(E_half)

# %%
# kind of a constant in the way it is been built
a_cell = []
b_cell = []
bR_cell = []

for i in range(N):
    a_cell.append(a_i)
    b_cell.append(b_i)
    bR_cell.append(bR_i)

# %%
E_half = np.array(E_half)
if E_half.max() > N:
    raise Exception("Error in the connections set")

E_G = np.concat([E_half, np.flip(E_half, axis=1)], axis=0)
V_G = np.arange(start=1, stop=N+1)
A_G = np.zeros((N, N))
D_G = np.zeros((N, N))
L_G = np.zeros((N, N))

for i in range(N):
    for j in range(N):
        is_in_array = np.any(np.all(E_G == [i+1, j+1], axis=1))

        if is_in_array:
            A_G[i, j] = 1

for i in range(N):
    D_G[i, i] = np.sum(A_G[i,:])

L_G = D_G - A_G

# %%
def A_i(i: int) -> np.ndarray:
    return np.array([
        [0, 1, 0, 0],
        [0, D[i]/M[i], -1/M[i], 0],
        [0, 0, -1/T[i], -1/T[i]],
        [0, 1/K[i], 0, -R[i]/K[i]]
    ])

def C_i(i: int) -> np.ndarray:
    return np.array([
        [1, 0, 0, 0]
    ]).reshape((1, 4))

# %%
A_cell = []
C_cell = []

for i in range(N):
    A_i_cell = []
    C_i_cell = []
    
    A_cell.append(A_i(i))
    C_cell.append(C_i(i))

# %%
sys = ct.ss(A_i(0), np.zeros(shape=(4, 1)), C_i(0), np.zeros(shape=(1, 1)))
np.linalg.eigvals(A_i(0))
# Out:
# array([ 0.        +0.j        ,  1.20556943+0.j        ,
#        -1.10278472+0.66545695j, -1.10278472-0.66545695j])

# %%
def phi_z(F: np.ndarray, z: np.ndarray, b: np.ndarray): # TODO: move to a local utils under project UIO or to the LMIS definition
    '''
        ### The parameters are given from the expressions and are used to generate Lmis for Theorem 1 of Coutinho et al.
        R = { x \in RR^n : F@x <= b} \\
        phi(z) = min{ b.T@w: F.T@w = z, w \in RR^f >= 0 }
    '''

    w = cp.Variable((b.shape[0], 1))
    constrains = []

    constrains += [ w >= 0]
    
    constrains += [ F.T@w == z ]

    prob = cp.Problem(cp.Minimize(b.T@w), constraints=constrains)
    result = prob.solve(solver=cp.MOSEK, verbose=False)

    return result

nx = []
ny = []

for i in range(N):
    nx_i = A_cell[i].shape[0]
    ny_i = C_cell[i].shape[0]
    
    nx.append(nx_i)
    ny.append(ny_i)

P_trace = 0
P_cell = []
L_till_cell = []

for i in range(N): # TODO: MAYBE fix this L_till_cell having 16 elements instead of Perm(n_z) - quite possible actually as the Upsilon is actually l sums of jk
    P_i = cp.Variable((nx[i], nx[i]), symmetric=True)
    P_cell.append(P_i)

    L_till_i_cell = []
    L_till_i = cp.Variable((nx[i], ny[i]))
    
    L_till_cell.append(L_till_i)

constrains = []

for i in range(N):

    P_trace += cp.trace(P_cell[i])
    constrains += [P_cell[i] >> eps] # the same as P > 0

    M = P_cell[i]@A_cell[i] - L_till_cell[i]@C_cell[i] + eta*P_cell[i]

    Upsilon = M + M.T
        
    constrains += [Upsilon << -eps]
        
    for j in range(a_cell[i].T.shape[0]):
        aj = np.expand_dims(a_cell[i].T[j], axis=1)
        phi = phi_z(a_cell[i].T, aj, bR_cell[i])
        sj = 1/(b_cell[i][j] - phi) * aj

        M = cp.bmat([
            [np.eye(1), sj.T],
            [sj       , P_i],
        ])
        constrains += [ M >> 0 ] # >= breaks -> i know why but cannot remember right now


prob = cp.Problem(cp.Minimize(P_trace), constraints=constrains)
result = prob.solve(solver=cp.MOSEK, verbose=True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.6.0
# ===============================================================================
# (CVXPY) Feb 25 07:59:25 PM: Your problem has 60 variables, 96 constraints, and 0 parameters.
# (CVXPY) Feb 25 07:59:25 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Feb 25 07:59:25 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Feb 25 07:59:25 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Feb 25 07:59:25 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Feb 25 07:59:25 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Feb 25 07:59:25 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Feb 25 07:59:25 PM: Applying reduction Dcp2Cone
# (CVXPY) Feb 25 07:59:25 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Feb 25 07:59:25 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Feb 25 07:59:25 PM: Applying reduction MOSEK
# (CVXPY) Feb 25 07:59:25 PM: Finished problem compilation (took 2.383e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Feb 25 07:59:25 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Feb 25 07:59:25 PM: Problem
# (CVXPY) Feb 25 07:59:25 PM:   Name                   :
# (CVXPY) Feb 25 07:59:25 PM:   Objective sense        : maximize
# (CVXPY) Feb 25 07:59:25 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Feb 25 07:59:25 PM:   Constraints            : 42
# (CVXPY) Feb 25 07:59:25 PM:   Affine conic cons.     : 0
# (CVXPY) Feb 25 07:59:25 PM:   Disjunctive cons.      : 0
# (CVXPY) Feb 25 07:59:25 PM:   Cones                  : 0
# (CVXPY) Feb 25 07:59:25 PM:   Scalar variables       : 0
# (CVXPY) Feb 25 07:59:25 PM:   Matrix variables       : 6 (scalarized: 60)
# (CVXPY) Feb 25 07:59:25 PM:   Integer variables      : 0
# (CVXPY) Feb 25 07:59:25 PM:
# (CVXPY) Feb 25 07:59:25 PM: Optimizer started.
# (CVXPY) Feb 25 07:59:25 PM: Presolve started.
# (CVXPY) Feb 25 07:59:25 PM: Linear dependency checker started.
# (CVXPY) Feb 25 07:59:25 PM: Linear dependency checker terminated.
# (CVXPY) Feb 25 07:59:25 PM: Eliminator started.
# (CVXPY) Feb 25 07:59:25 PM: Freed constraints in eliminator : 0
# (CVXPY) Feb 25 07:59:25 PM: Eliminator terminated.
# (CVXPY) Feb 25 07:59:25 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Feb 25 07:59:25 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Feb 25 07:59:25 PM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Feb 25 07:59:25 PM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY) Feb 25 07:59:25 PM: Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# (CVXPY) Feb 25 07:59:25 PM: Presolve terminated. Time: 0.02
# (CVXPY) Feb 25 07:59:25 PM: Optimizer  - threads                : 10
# (CVXPY) Feb 25 07:59:25 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Feb 25 07:59:25 PM: Optimizer  - Constraints            : 42
# (CVXPY) Feb 25 07:59:25 PM: Optimizer  - Cones                  : 0
# (CVXPY) Feb 25 07:59:25 PM: Optimizer  - Scalar variables       : 0                 conic                  : 0
# (CVXPY) Feb 25 07:59:25 PM: Optimizer  - Semi-definite variables: 6                 scalarized             : 60
# (CVXPY) Feb 25 07:59:25 PM: Factor     - setup time             : 0.00
# (CVXPY) Feb 25 07:59:25 PM: Factor     - dense det. time        : 0.00              GP order time          : 0.00
# (CVXPY) Feb 25 07:59:25 PM: Factor     - nonzeros before factor : 315               after factor           : 315
# (CVXPY) Feb 25 07:59:25 PM: Factor     - dense dim.             : 0                 flops                  : 7.66e+03
# (CVXPY) Feb 25 07:59:25 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Feb 25 07:59:25 PM: 0   1.0e+00  1.0e+00  1.0e+00  0.00e+00   2.400000000e-08   -0.000000000e+00  1.0e+00  0.02
# (CVXPY) Feb 25 07:59:25 PM: 1   2.0e-01  2.0e-01  9.5e-02  7.36e-01   2.328056418e-08   -1.388699578e-02  2.0e-01  0.03
# (CVXPY) Feb 25 07:59:25 PM: 2   2.1e-02  2.1e-02  3.1e-03  9.91e-01   2.525894760e-08   2.643244648e-03   2.1e-02  0.03
# (CVXPY) Feb 25 07:59:25 PM: 3   2.0e-05  2.0e-05  8.5e-08  9.97e-01   2.535550951e-08   3.534216600e-06   2.0e-05  0.03
# (CVXPY) Feb 25 07:59:25 PM: 4   7.6e-09  7.6e-09  7.0e-13  1.00e+00   2.536353322e-08   2.553850629e-08   7.6e-09  0.03
# (CVXPY) Feb 25 07:59:25 PM: Optimizer terminated. Time: 0.03
# (CVXPY) Feb 25 07:59:25 PM:
# (CVXPY) Feb 25 07:59:25 PM:
# (CVXPY) Feb 25 07:59:25 PM: Interior-point solution summary
# (CVXPY) Feb 25 07:59:25 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Feb 25 07:59:25 PM:   Solution status : OPTIMAL
# (CVXPY) Feb 25 07:59:25 PM:   Primal.  obj: 2.5363533218e-08    nrm: 2e+00    Viol.  con: 3e-08    barvar: 0e+00
# (CVXPY) Feb 25 07:59:25 PM:   Dual.    obj: 2.5538506293e-08    nrm: 1e+00    Viol.  con: 0e+00    barvar: 8e-09
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Feb 25 07:59:25 PM: Problem status: optimal
# (CVXPY) Feb 25 07:59:25 PM: Optimal value: 2.554e-08
# (CVXPY) Feb 25 07:59:25 PM: Compilation took 2.383e-02 seconds
# (CVXPY) Feb 25 07:59:25 PM: Solver (including time spent in interface) took 4.382e-02 seconds
# <>:2: SyntaxWarning: invalid escape sequence '\i'
# <>:2: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\luiza\AppData\Local\Temp\ipykernel_9964\827673011.py:2: SyntaxWarning: invalid escape sequence '\i'
#   '''

# %%
is_positive_defined = []
for i in range(N):
    i_is_positive_defined = True if all(np.linalg.eig(P_cell[i].value).eigenvalues > 0) else False
print(f'e.g.: P[1] = \n{P_cell[0].value}')
print(f"The solution is \'{prob.status}\', with Trace(P) = {result:.2f} and P is {"Positive Defined" if all(is_positive_defined) else "NOT Positive Defined"}")
# Out:
# e.g.: P[1] =
# [[ 9.04023281e-09 -3.00320780e-09 -3.99683975e-09  1.11436272e-09]
#  [-3.00320780e-09 -1.88325385e-09  2.32985444e-09 -1.94693007e-09]
#  [-3.99683975e-09  2.32985444e-09  7.28827087e-09  5.97919954e-09]
#  [ 1.11436272e-09 -1.94693007e-09  5.97919954e-09  8.30456598e-09]]
# The solution is 'optimal', with Trace(P) = 0.00 and P is Positive Defined

# %%
L_cell = []

for i in range(N):
    P_i_inv = np.linalg.inv(P_cell[i].value)

    L_cell.append(P_i_inv@L_till_cell[i].value)

# %%
L_cell
# Out:
# [array([[ 2.05340657e+08],
#         [ 9.55594320e+07],
#         [ 2.10796934e+08],
#         [-1.56922514e+08]]),
#  array([[ 1.59806964e+08],
#         [-3.10098565e+07],
#         [-1.79945323e+06],
#         [-4.27048888e+07]]),
#  array([[ 2.28503273e+08],
#         [-3.57360128e+07],
#         [-2.41382620e+07],
#         [-1.49789631e+08]])]

# %%
# simulação

def f_x(i) -> np.ndarray[float]:
    return A_i(i)

def g_x(i, Adj) -> np.ndarray[float]:
    g = []

    for j in range(Adj[i].shape[1]):
        if j == i or Adj[j] == 0:
            continue

        gd_ij = np.array([
            0,
            -Adj[i][j]/M[i],
            0,
            0
        ])

        g.append(gd_ij)


    return np.array(g)

def d_x(x_i: np.ndarray[float], x_j_cell: list[np.ndarray[float]]) -> np.ndarray[float]:
    d = []

    for x_j in x_j_cell:
        d_ij = math.sin(x_i[0] - x_j[0])

        d.append(d_ij)

    return np.array(d)

def h_x(i, x_i):
    return C_cell[i]@x_i

def Gamma_inv(x_i: np.ndarray, y_i: np.ndarray, x_j_cell: list[np.ndarray]): # has the lie derivative varing for each

    Gamma = None
    for j in range(len(x_j_cell)): # columns
        Gamma_i = np.zeros(shape=(y_i.shape[0], 1))
        Gamma_i[0] = -1 # HARDCODED

        if Gamma is None:
            Gamma = Gamma_i
        else:
            Gamma = np.concat([Gamma, Gamma_i], axis=1)

    print(Gamma)

    return np.linalg.pinv(Gamma)

def Q_x(x_i: np.ndarray, y_i: np.ndarray, x_j_cell: list[np.ndarray], i: int, t: float):
    g_i = []
    for j in range(len(x_j_cell)):
        g_i.append(g_ij(x_i, x_j_cell[j]))
    g_i = np.array(g_i).T.squeeze().reshape((2, -1))

    G_i = Gamma_inv(x_i, y_i, x_j_cell)
    Q  = g_i@G_i

    # if t == 0.0:
    #     print(f"syst: {i+1} \ng = {g_i} \nGamma = \n{G_i} \nQ = \n{Q}\n\n")

    return Q

def Psi_x(x_i: np.ndarray, y_i: np.ndarray, x_j_cell: list[np.ndarray], mi: float):
    Psi = lambda x: -x[0] + mi*(1 - x[0]**2)*x[1]

    Psi_cell = []
    Psi_cell.append(Psi(x_i))

    for j in range(y_i.shape[0]-1):
        x_j = x_j_cell[j]
        Psi_cell.append(Psi(x_j))
    
    Psi_cell = np.array(Psi_cell).reshape((len(Psi_cell), 1))

    return Psi_cell

def Y_levants(xj_cell: list[list[np.ndarray, list[np.ndarray]]], cp: float):
    Y_l = []

    for xj in xj_cell:
        x_i = xj[0]
        x_j_cell = xj[1]

        Y_i = -x_i[0] + mi*(1 - x_i[0]**2)*x_i[1]
        for x_j in x_j_cell:
            Y_i += - cp*(math.tanh(x_j[1] - x_i[1]))
        Y_l.append(Y_i)
    Y_l = np.array(Y_l).reshape((len(xj_cell), 1))

    # for x_i in x_i_cell:
    #     Y_i = -x_i[0] + mi*(1 - x_i[0]**2)*x_i[1]
    #     for x_j in x_j_cell:
    #         Y_i += - cp*(math.tanh(x_j[2] - x_i[2]))
    #     Y_l.append(Y_i)
    # Y_l = np.array(Y_l).reshape((len(x_i_cell), 1))

    return Y_l

def model(t: float, x: np.ndarray[float], N: int, mi: float, cp: float, dist_hist: list[list]):
    print(f"t={t}s")

    # TODO: ADAPT THIS
    xdot = np.zeros(shape=x.shape) # half are the real states and the other half is the observer
    xdot = np.expand_dims(xdot, axis=1)

    nx = int(x.shape[0]/(2*N))

    x_i_cell = []
    x_hat_i_cell = []

    for i in range(N):
        id = i * nx
        id_hat = id + N*nx

        x_i_cell.append(x[id:id+nx])
        x_hat_i_cell.append(x[id_hat:id_hat+nx])

    dist_hist[0].append(t)
    for i in range(N):
        id = i * nx
        id_hat = id + N*nx

        x_i = x_i_cell[i]
        x_hat_i = x_hat_i_cell[i]
        x_j_cell = []

        alpha_i = [np.array([x_i[0]**2])]

        for a in range(A_G[i].shape[0]):
            if A_G[i][a] == 1:
                x_j_cell.append(x_i_cell[a])

        # missing levants differentiator
        d_i = gd_x(x_i, x_j_cell, cp) # g*d - coupling
        d_i_decoupled = gd_x_decoupled(x_i, x_j_cell, cp)

        #######
        xj_cell = [[x_i, x_j_cell]]

        xdot[id:id+nx] = f_x(x_i, mi) + d_i

        yy = h_x(x_i)
        y_i = h_x(x_hat_i)
        Q = Q_x(x_hat_i, y_i, x_j_cell, i, t)
        Psi = Psi_x(x_hat_i, y_i, x_j_cell, mi)
        Y = Y_levants(xj_cell, cp)
        L = L_alpha(alpha_i, z_i_interval, k_perms, L_cell[i])

        delta = np.expand_dims(yy - y_i, axis=1)
        
        d_hat = (Y - Psi) # TODO: remove
        d_hat_decoupled = Gamma_inv(x_hat_i, y_i, x_j_cell)@(Y - Psi)
        xdot[id_hat:id_hat+nx] = f_x(x_hat_i, mi) + Q@(Y - Psi) + L@delta

        if len(dist_hist) < i + 2:
            dist_hist.append([[], []])

        # if i == 0 and t == 0:
        #     print(Gamma_inv(x_hat_i, y_i, x_j_cell))
        #     print(d_hat)
        #     print("***")
        #     print(d_i_decoupled)
        #     print(d_hat_decoupled)
        #     print("##########")
        
        dist_hist[i+1][0].append(d_i_decoupled)

        dist_hist[i+1][1].append(d_hat_decoupled)

    return xdot.flatten()

# %%
if x0.shape[0] != A_cell[0][0].shape[0]*2*N:
    raise Exception("error in X0 array")

sim_time = (0, time)
dist_hist = [[]]

result = solve_ivp(model, sim_time, x0, args=(N, mi, coupling_factor, dist_hist), method="BDF", dense_output=True)  # LSODA
t = result.t
x = result.y
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[255], line 2
#       1 if x0.shape[0] != A_cell[0][0].shape[0]*2*N:
# ----> 2     raise Exception("error in X0 array")
#       4 sim_time = (0, time)
#       5 dist_hist = [[]]
#
# Exception: error in X0 array

# %%
for i in range(0, len(dist_hist)):
    dist_hist[i] = np.array(dist_hist[i])

# %%
def plot_graph(x, nx):
    plt.figure(dpi=150, constrained_layout=True)
    # plt.suptitle(f'{N}-Interconnected Oscilators', y=1.0)

    cols = 2
    rows = math.ceil(N/cols)

    for i in range(N):
        ind = i * nx
        ind_hat = ind + N*nx

        plt.subplot(rows, cols, i+1)
        plt.title(f"Oscilator {i+1}", fontsize=8)
        plt.scatter(x0[ind], x0[ind+1], s=30, facecolors='none', edgecolors='k') #, label=f'$\\mathbf{{x}}_{i+1}$')
        plt.plot(x[ind, :], x[ind+1, :], 'k') #, label=f'$\\mathbf{{x}}_{i+1}$')
        plt.plot(x[ind_hat, :], x[ind_hat+1, :], 'r--', linewidth=1) #, label=f'$\\mathbf{{\\hat{{x}}}}_{i+1}$')
        # plt.xlabel("$x_1$")
        # plt.ylabel("$x_2$")
        # plt.legend()
        
        plt.grid(which='both')
    
    legend = plt.figlegend([r'$\mathbf{x}_0$', r'$\mathbf{x}$', r'$\mathbf{\hat{x}}$'], loc = 'lower center', ncol = 3,  bbox_to_anchor=(0.5, -0.1))

    dir = os.path.join(os.curdir, f'.figures/')
    if not os.path.isdir(dir):
        os.mkdir(dir)

    plt.savefig(f".figures/dynamics_{N}", dpi=600, bbox_inches='tight', bbox_extra_artists=[legend])
    plt.show()

# %%
plt.figure(figsize=(3.5, 3.5), dpi=100)
ntx.draw(G, with_labels=True, font_weight='bold')
plt.savefig(f".figures/grafo_{N}", dpi=600)
plt.plot()
# Out:
# []

# %%
nx = A_cell[0][0].shape[0]
plot_graph(x, nx)

# %%
gg = np.array([
    [0, 0],
    [-1, -1]
])

# %%
np.linalg.pinv(gg)
# Out:
# array([[ 0. , -0.5],
#        [ 0. , -0.5]])

# %%
dist_hist[1][1, :, 1]
# Out:
# array([[-1.02501712e+01],
#        [-1.02501703e+01],
#        [-1.02501712e+01],
#        [-1.02501708e+01],
#        [-1.02501710e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501694e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501712e+01],
#        [-1.02501537e+01],
#        [-1.02501537e+01],
#        [-1.02501363e+01],
#        [-1.02501363e+01],
#        [-1.02499619e+01],
#        [-1.02499620e+01],
#        [-1.02497878e+01],
#        [-1.02497880e+01],
#        [-1.02488654e+01],
#        [-1.02488653e+01],
#        [-1.02479542e+01],
#        [-1.02479543e+01],
#        [-1.02470601e+01],
#        [-1.02470602e+01],
#        [-1.02413571e+01],
#        [-1.02413555e+01],
#        [-1.02386988e+01],
#        [-1.02386982e+01],
#        [-1.02405439e+01],
#        [-1.02405495e+01],
#        [-1.02902311e+01],
#        [-1.02902203e+01],
#        [-1.04195083e+01],
#        [-1.04193892e+01],
#        [-1.06300687e+01],
#        [-1.06296481e+01],
#        [-1.09127332e+01],
#        [-1.09120507e+01],
#        [-1.19082728e+01],
#        [-1.19113553e+01],
#        [-1.30447603e+01],
#        [-1.30597022e+01],
#        [-1.41423159e+01],
#        [-1.41671863e+01],
#        [-1.51149177e+01],
#        [-1.51373354e+01],
#        [-1.59257064e+01],
#        [-1.59398776e+01],
#        [-1.68000546e+01],
#        [-1.68265477e+01],
#        [-1.73881389e+01],
#        [-1.74370615e+01],
#        [-1.77892041e+01],
+00],
#        [ 1.62487426e+00],
#        [ 1.62487426e+00],
#        [ 1.62487426e+00],
#        [ 1.62487426e+00],
#        [ 1.62487426e+00],
#        [ 1.62487426e+00],
#        [ 1.62487426e+00],
#        [ 1.62487426e+00],
#        [ 1.62487426e+00],
#        [ 1.62487426e+00],
#        [ 1.62487426e+00],
#        [ 1.62496097e+00],
#        [ 1.77170849e+00],
#        [ 1.77157533e+00],
#        [ 1.74690151e+00],
#        [ 1.74682880e+00],
#        [ 1.78956774e+00],
#        [ 1.78951741e+00],
#        [ 1.74579145e+00],
#        [ 1.74585679e+00],
#        [ 1.74585131e+00],
#        [ 1.60837735e+00],
#        [ 1.60869871e+00],
#        [ 1.60867543e+00],
#        [ 1.67966996e+00],
#        [ 1.67972314e+00],
#        [ 1.58222781e+00],
#        [ 1.58225405e+00],
#        [ 1.58225271e+00],
#        [ 1.62841865e+00],
#        [ 1.62842505e+00],
#        [ 1.56695937e+00],
#        [ 1.56695532e+00],
#        [ 1.49525396e+00],
#        [ 1.49525394e+00],
#        [ 1.41333966e+00],
#        [ 1.41334507e+00],
#        [ 1.32135354e+00],
#        [ 1.32135851e+00],
#        [ 9.45636717e-01],
#        [ 9.47178053e-01],
#        [ 4.82363248e-01],
#        [ 4.87427858e-01],
#        [-2.47553364e-02],
#        [-1.80251495e-02],
#        [-1.80540682e-02],
#        [-5.18691762e-01],
#        [-5.15403746e-01],
#        [-5.15116914e-01],
#        [-3.35345736e-01],
#        [-3.34135395e-01],
#        [-6.30606110e-01],
#        [-6.31769329e-01],
#        [-6.31361801e-01],
#        [-5.26509358e-01],
#        [-5.26874100e-01],
#        [-7.08285733e-01],
#        [-7.08824701e-01],
#        [-8.76752960e-01],
#        [-8.77200855e-01],
#        [-1.02934013e+00],
#        [-1.02973344e+00],
#        [-1.32855528e+00],
#        [-1.33322410e+00],
#        [-1.33316103e+00],
#        [-1.51753409e+00],
#        [-1.52777587e+00],
#        [-1.52784936e+00],
#        [-1.62502052e+00],
#        [-1.63771937e+00],
#        [-1.63771707e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62501573e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502049e+00],
#        [-1.62502063e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.62502052e+00],
#        [-1.63771756e+00],
#        [-1.60119123e+00],
#        [-1.60550900e+00],
#        [-1.65783793e+00],
#        [-1.65971772e+00],
#        [-1.70336461e+00],
#        [-1.70417295e+00],
#        [-1.70435044e+00],
#        [-1.68489573e+00],
#        [-1.68506240e+00],
#        [-1.68514310e+00],
#        [-1.70965767e+00],
#        [-1.70955156e+00],
#        [-1.73494305e+00],
#        [-1.73485471e+00],
#        [-1.76214260e+00],
#        [-1.76212190e+00],
#        [-1.85095007e+00],
#        [-1.85053846e+00],
#        [-1.95439878e+00],
#        [-1.95041209e+00],
#        [-2.05230674e+00],
#        [-2.04390597e+00],
#        [-2.11886204e+00],
#        [-2.10968675e+00],
#        [-2.10949960e+00],
#        [-2.07967442e+00],
#        [-2.07819184e+00],
#        [-2.10511518e+00],
#        [-2.10494868e+00],
#        [-2.12277714e+00],
#        [-2.12289149e+00],
#        [-2.13125415e+00],
#        [-2.13125999e+00],
#        [-2.11962910e+00],
#        [-2.11928691e+00],
#        [-2.07456623e+00],
#        [-2.07438860e+00],
#        [-2.00592617e+00],
#        [-2.00609447e+00],
#        [-1.92347140e+00],
#        [-1.92368649e+00],
#        [-1.76901463e+00],
#        [-1.76845438e+00],
#        [-1.61543538e+00],
#        [-1.61434102e+00],
#        [-1.47232629e+00],
#        [-1.47170651e+00],
#        [-1.34400991e+00],
#        [-1.34410874e+00],
#        [-1.23143573e+00],
#        [-1.23177611e+00],
#        [-1.09858232e+00],
#        [-1.09902259e+00],
#        [-4.99947914e-01],
#        [-4.99828711e-01],
#        [-4.99824820e-01],
#        [-5.03665469e-01],
#        [-5.03157175e-01],
#        [-5.03175823e-01],
#        [-5.03172148e-01],
#        [-5.19312747e-01],
#        [-5.18362493e-01],
#        [-5.18517936e-01],
#        [-5.74507456e-01],
#        [-5.77415649e-01],
#        [-5.77844402e-01],
#        [-6.93742751e-01],
#        [-7.04777608e-01],
#        [-8.40398894e-01],
#        [-8.46663165e-01],
#        [-8.46367683e-01],
#        [-9.32039055e-01],
#        [-9.32173719e-01],
#        [-9.31967135e-01],
#        [-9.69739893e-01],
#        [-9.69771356e-01],
#        [-9.69705492e-01],
#        [-9.84148619e-01],
#        [-9.84370128e-01],
#        [-9.84353146e-01],
#        [-9.91341373e-01],
#        [-9.91455357e-01],
#        [-9.91450987e-01],
#        [-9.95143729e-01],
#        [-9.95163383e-01],
#        [-9.97236485e-01],
#        [-9.97228550e-01],
#        [-9.97229146e-01],
#        [-9.97641026e-01],
#        [-9.97640278e-01]])

# %%
# for i in range(1, N+1):
for i in range(1, 1+1):
    plt.plot(dist_hist[0], dist_hist[i][0, :, 0] + dist_hist[i][0, :, 1] + dist_hist[i][0, :, 2] + dist_hist[i][0, :, 3], label=f"$d_{i}$")
    plt.plot(dist_hist[0], -1*(dist_hist[i][1, :, 0] + dist_hist[i][1, :, 1] + dist_hist[i][1, :, 2] + dist_hist[i][1, :, 3]), label=f"$\hat{{d}}_{i}$")
    plt.plot(dist_hist[0], dist_hist[i][0, :, 0] - dist_hist[i][1, :, 0], label=f'$e_{{d_{{{i}1}}}}$')
    plt.plot(dist_hist[0], dist_hist[i][0, :, 0] - dist_hist[i][1, :, 1], label=f'$e_{{d_{{{i}2}}}}$')
    plt.plot(dist_hist[0], dist_hist[i][0, :, 0] - dist_hist[i][1, :, 2], label=f'$e_{{d_{{{i}3}}}}$')
    plt.plot(dist_hist[0], dist_hist[i][0, :, 0] - dist_hist[i][1, :, 3], label=f'$e_{{d_{{{i}4}}}}$')

    # plt.plot(dist_hist[0], dist_hist[i][0, :, 0] - dist_hist[i][1, :, 0], label=f'$e_{{d_{i}}}$') # original comparison

plt.ylim([-10, 10])
# plt.xlim([-0.2, 4.2])
plt.legend()
plt.grid()
plt.savefig(f".figures/dist_{N}", dpi=600)
plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\h'
# <>:4: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\luiza\AppData\Local\Temp\ipykernel_48924\1289827018.py:4: SyntaxWarning: invalid escape sequence '\h'
#   plt.plot(dist_hist[0], -1*(dist_hist[i][1, :, 0] + dist_hist[i][1, :, 1] + dist_hist[i][1, :, 2] + dist_hist[i][1, :, 3]), label=f"$\hat{{d}}_{i}$")

# %%
import numpy as np
Y41 = 2
Y42 = 3
Y43 = 4

M4 = 2

g41 = (-Y41/M4)
g42 = (-Y42/M4)
g43 = (-Y43/M4)

dg41 = (g41 - (g42 + g43))
dg42 = (g42 - (g41 + g43))
dg43 = (g43 - (g41 + g42))

# h1_till = fx*(g41 - (g42 + g43))
# h2_till = fx*(g42 - (g41 + g43))
# h3_till = fx*(g43 - (g41 + g42))

Gamma_t = np.array([
    [g41*dg41, g42*dg41, g43*dg41],
    [g41*dg42, g42*dg42, g43*dg42],
    [g41*dg43, g42*dg43, g43*dg43]
])

Gamma_tt = np.array([g41 + g42 + g43]).reshape(1, 1)

# %%
(Gamma_tt.T@Gamma_tt)**-1@Gamma_tt, np.linalg.det((Gamma_tt.T@Gamma_tt))
# (Gamma_t.T@Gamma_t), np.linalg.det(Gamma_t.T@Gamma_t)
# Out:
# (array([[-0.22222222]]), np.float64(20.250000000000004))
